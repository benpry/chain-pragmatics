# %%
import pandas as pd
from pyprojroot import here

# %%
# constants
corpus = "katz"
gpt_version = "curie"
prompt_type = "QUD_v3"
temp = 0.9
K = 10

# %%
df_results = pd.read_csv(here(f"data/model-outputs/model_responses_corpus={corpus}-gpt={gpt_version}-prompt={prompt_type}-k={K}-temp={temp}.csv"))

# %%
df_results[["Statement", "Good (4)", "model_response"]]
# Out:
#                                             Statement  \
# 0                               The mind is a sponge.
# 1                               Truth is a labyrinth.
# 2                   Our environment is a chamber pot.
# 3                             Evolution is a lottery.
# 4                            A forest is a harmonica.
# ..                                                ...
# 95                            Snow is winter's robes.
# 96                      A good lover is a teddy bear.
# 97                         A pond is nature's mirror.
# 98               Skyscrapers are honeycombs of glass.
# 99  The fall of an empire is the sunset of civiliz...
#
#                                              Good (4)  \
# 0              The mind is capable of learning a lot.
# 1                          Truth can be hard to find.
# 2                          Our environment is filthy.
# 3                            Evolution involves luck.
# 4                There is always noise in the forest.
# ..                                                ...
# 95                            Snow can be a covering.
# 96                            A good lover is cuddly.
# 97                              A pond is reflective.
# 98  Skyscrapers have an intricate geometric struct...
# 99  The fall of an empire is the end of civilization.
#
#                                        model_response
# 0   The speaker is addressing the question "How do...
# 1   The speaker is addressing the question "What i...
# 2   The speaker is addressing the question "How is...
# 3   The speaker is addressing the question "How do...
# 4   The speaker is addressing the question "How do...
# ..                                                ...
# 95  The speaker is addressing the question "What d...
# 96  The speaker is addressing the question "What d...
# 97  The speaker is addressing the question "How do...
# 98  \nThe speaker is addressing the question "What...
# 99  \n\nThe speaker is addressing the question "Wh...
#
# [100 rows x 3 columns]

# %%
for index, row in df_results.sample(frac=1).iterrows():
    last_prompt = row["prompt"].split("###")[-1]
    print(last_prompt)
    
    print(row["model_response"])
    print("\n\n")
# Out:
# "Extravagance is poison ivy."
#
# a) Extravagance is important.
# b) Extravagance is a lack of restraint.
# c) Extravagance causes a rash.
# d) Extravagance causes problems but its hard to eliminate.
#
# The speaker is addressing the question "Why is extravagance important?"
# The speaker answers this question by comparing extravagance to poison ivy.
# Poison ivy is important because it protects other plants from being eaten, so the speaker is saying a) extravagance is important.
#
#
#
# "Peace is a wild wood-dove."
#
# a) Peace is elusive.
# b) Peace is beautiful.
# c) Peace is everywhere.
# d) Peace is the absense of violence.
#
# The speaker is addressing the question "Where can I find peace?"
# The speaker answers this question by comparing peace to a wood-dove.
# A wood-dove is elusive, so the speaker is saying a) peace is elusive.
#
#
#
# "The mind is a sponge."
#
# a) The mind enables a person to be aware.
# b) The mind is capable of forgetting a lot.
# c) The mind has a fixed capacity.
# d) The mind is capable of learning a lot.
#
# The speaker is addressing the question "How does the mind work?"
# The speaker answers this question by comparing the mind to a sponge.
# A sponge absorbs water, so the speaker is saying a) the mind enables a person to be aware.
#
#
#
# "Waves are the sailor's steed."
#
# a) Waves move sailors through water.
# b) Waves stabilize sailors.
# c) Waves need to be fed by sailors.
# d) Waves are the natural movements of water.
#
# The speaker is addressing the question "What is the role of waves?"
# The speaker answers this question by comparing waves to the sailor's steed.
# A sailor rides waves to move through water, so the speaker is saying a) waves move sailors through water.
# ###
#
# "Rocks are the Earth's backbone."
#
# a) Rocks provide stability to the Earth.
# b) Rocks are heavy.
# c) Rocks are cold.
# d) Rocks are alive.
#
# Let's think step by step.
#
# The speaker is addressing the question "What does rocks do for the Earth?"
# The speaker answers this question by comparing rocks to the Earth's backbone.
# Rocks provide stability to the Earth, so the speaker is saying b) rocks are heavy.
#
#
#
# "A dream is a solar eclipse."
#
# a) A dream usually involves mental imagery.
# b) A dream is a major event.
# c) A dream is a bright event.
# d) A dream is a mundane event.
#
# The speaker is addressing the question "What is a dream?"
# The speaker answers this question by comparing a dream to a solar eclipse.
# A solar eclipse is a bright event, so the speaker is saying c) a dream is a bright event.
#
#
#
# "A folk dance is a braid of steps."
#
# a) A folk dance can be learned.
# b) A folk dance is intricate.
# c) A folk dance is a cultural expression.
# d) A folk dance is simple.
#
# The speaker is addressing the question "What is the purpose of a folk dance?"
# The speaker answers this question by comparing a folk dance to a braid of steps.
# A braid of steps is a simple way to do something, so the speaker is saying d) a folk dance is simple.
#
#
#
# "Dreams are the movies of the mind."
#
# a) Dreams are what people remember from sleep.
# b) Dreams are boring.
# c) Dreams require tickets.
# d) Dreams are personal entertainment.
#
# The speaker is addressing the question "What are dreams?"
# The speaker answers this question by comparing dreams to movies.
# Movies are what people remember after watching them, so the speaker is saying a) dreams are what people remember from sleep.
#
#
#
# "Marriage is an alloy."
#
# a) Marriage is a formal union of two people.
# b) Marriage keeps people together.
# c) Marriage is temporary.
# d) Marriage is painful.
#
# The speaker is addressing the question "What is the purpose of marriage?"
# The speaker answers this question by comparing marriage to an alloy.
# An alloy is a mixture of two different metals, so the speaker is saying c) marriage is temporary.
#
#
#
# "Education is a lantern."
#
# a) Education is learning at school.
# b) Education is expensive.
# c) Education is fire.
# d) Education helps to reveal reality.
#
# The speaker is addressing the question "What is the purpose of education?"
# The speaker answers this question by comparing education to a lantern.
# A lantern casts light and reveals things, so the speaker is saying a) education is learning at school.
#
#
#
# "Money is a lubricant."
#
# a) Money is a medium of economic exchange.
# b) Money makes it harder to get things done.
# c) Money helps make things happen.
# d) Money is easy to spend.
#
#
# The speaker is addressing the question "How does money work?"
# The speaker answers this question by comparing money to a lubricant.
# Lubricants make things move smoothly, so the speaker is saying c) money helps make things happen.
#
#
#
# "Responsibility is a shackle."
#
# a) Responsibility is a virtue.
# b) Responsibility is exercise.
# c) Responsibility is confining.
# d) Responsibility is easy.
#
# The speaker is addressing the question "How is responsibility a virtue?"
# The speaker answers this question by comparing responsibility to a shackle.
# A shackle is a restraint that keeps someone in place, so the speaker is saying a) responsibility is a virtue.
#
#
#
# "Fame is a credit card."
#
# a) Fame is worth money.
# b) Fame is temporary.
# c) Fame is easy to get.
# d) Fame is when you are known by a lot of people.
#
# The speaker is addressing the question "How does fame work?"
# The speaker answers this question by comparing fame to a credit card.
# A credit card gives you access to money, so the speaker is saying c) fame is easy to get.
#
#
#
# "A wave is a tick of a clock."
#
# a) A wave is quiet.
# b) A wave is slow.
# c) A wave is fast.
# d) A wave is a hand gesture.
#
# The speaker is addressing the question "What is a wave's role in time?"
# The speaker answers this question by comparing a wave to a tick of a clock.
# A tick of a clock marks the passage of time, so the speaker is saying c) a wave is fast.
#
#
#
# "The skyscraper is the giraffe of buildings."
#
# a) The skyscraper moves slowly.
# b) The skyscraper is a company headquarters.
# c) The skycraper is the smallest of buildings.
# d) The skyscraper is the tallest of buildings.
#
# The speaker is addressing the question "What is the skyscraper's role?"
# The speaker answers this question by comparing the skyscraper to the giraffe.
# The giraffe is the tallest of animals, so the speaker is saying c) the skycraper is the smallest of buildings.
#
#
#
# "The subconscious is an arena."
#
# a) It is possible to watch the subconscious.
# b) The subconscious is open and unconstrained.
# c) The subconscious is hidden.
# d) The subconscious is the part of the mind that is inaccessible to people.
#
# The speaker is addressing the question "What is the subconscious?"
# The speaker answers this question by comparing the subconscious to an arena.
# An arena is a place where people can fight or perform, so the speaker is saying a) it is possible to watch the subconscious.
#
#
#
# "A broken heart is a shattered mirror, reflecting life in pieces."
#
# a) A broken heart is failed organ.
# b) Romatic grief, though traumatic, can be violent.
# c) Romantic grief, though traumatic, can be a learning process.
# d) Romatic grief, though traumatic, can be worthless.
#
# The speaker is addressing the question "How does a broken heart feel?"
# The speaker answers this question by comparing a broken heart to a shattered mirror.
# A shattered mirror reflects life in pieces, so the speaker is saying d) a broken heart is failed organ.
#
#
#
# "A fan is a private summer's breeze."
#
# a) A fan is a tool for moving air around.
# b) A fan is refreshing.
# c) A fan is hot.
# d) A fan is uncomfortable.
#
#
# The speaker is addressing the question "What does a fan do?"
# The speaker answers this question by comparing a fan to a summer's breeze.
# A summer's breeze moves air around, so the speaker is saying a) a fan is a tool for moving air around.
#
#
#
# "The unconscious is the kitchen of ideas."
#
# a) Ideas become worse through unconscious processes.
# b) Ideas become better through unconscious processes.
# c) Ideas become different through unconscious processes.
# d) The unconscious is the part of the mind that is inaccessible to people.
#
#
#
# The speaker is addressing the question "How does the unconscious work?"
# The speaker answers this question by comparing the unconscious to the kitchen of ideas.
# The kitchen of ideas is where people cook their food, so the speaker is saying a) ideas become worse through unconscious processes.
#
#
#
# "Snow is winter's robes."
#
# a) Snow can be warm.
# b) Snow can be a covering.
# c) Snow can be see-through.
# d) Snow is frozen water that falls from the sky.
#
# The speaker is addressing the question "What does snow do?"
# The speaker answers this question by comparing snow to winter's robes.
# Winter's robes keep people warm, so the speaker is saying a) snow can be warm.
#
#
#
# "Skyscrapers are the giraffes of the city."
#
# a) Skyscrapers are the smallest of buildings.
# b) Skyscrapers are slow movers.
# c) Skyscrapers are the tallest of buildings.
# d) Skyscrapers are usually office buildings.
#
# The speaker is addressing the question "What is the tallest building in the city?"
# The speaker answers this question by comparing skyscrapers to giraffes.
# Giraffes are the tallest animals on Earth, so the speaker is saying c) skyscrapers are the tallest of buildings.
#
#
#
# "Criticism is the helpful medicine only friends can prescribe."
#
# a) Criticism is necessary and best heard from friends.
# b) Criticism is a kind of feedback.
# c) Criticism is necessary but never from friends.
# d) Criticism is more painful from friends.
#
#
# The speaker is addressing the question "How is criticism helpful?"
# The speaker answers this question by comparing criticism to helpful medicine.
# Medicine is necessary to stay healthy, so the speaker is saying a) criticism is necessary and best heard from friends.
#
#
#
# "Conscience is a thorn in the mind."
#
# a) Conscience is inconvenient and joyful.
# b) Conscience is inconvenient and painful.
# c) Conscience is convenient and joyful.
# d) Conscience is a person's inner voice.
#
#
# The speaker is addressing the question "What is conscience?"
# The speaker answers this question by comparing conscience to a thorn.
# A thorn is inconvenient and causes pain, so the speaker is saying c) conscience is inconvenient and joyful.
#
#
#
# "The wind is a hammer driving heads of rain before it."
#
# a) Wind is the natural movement of air.
# b) The wind moves rain forcefully.
# c) The wind moves rain into wood.
# d) The wind moves rain gently.
#
#
#
# The speaker is addressing the question "What does the wind do?"
# The speaker answers this question by comparing the wind to a hammer.
# A hammer drives nails into wood, so the speaker is saying c) the wind moves rain into wood.
#
#
#
# "A scientist is a spawning trout."
#
# a) Scientists have few ideas.
# b) Scientists have lots of ideas.
# c) Scientists have lots of friends.
# d) A scientist is a worker.
#
# The speaker is addressing the question "What is a scientist's role?"
# The speaker answers this question by comparing a scientist to a spawning trout.
# A spawning trout has few eggs, so the speaker is saying a) scientists have few ideas.
#
#
#
# "The stars are signposts. "
#
# a) The stars are fireballs.
# b) The stars guide travelers.
# c) The stars block travelers.
# d) The stars hide information.
#
#
#
# The speaker is addressing the question "What does the stars tell us about our world?"
#
# The speaker answers this question by comparing the stars to signposts.
# Signposts guide travelers to their destination, so the speaker is saying b) the stars guide travelers.
#
#
#
# "Despair is a living tree feeding on death."
#
# a) Despair is sustained by positivity.
# b) Despair tastes bad.
# c) Despair is the absence of hope.
# d) Despair is sustained by negativity.
#
# The speaker is addressing the question "How does despair feel?"
# The speaker answers this question by comparing despair to a living tree.
# A living tree feeds on death, so the speaker is saying c) despair tastes bad.
#
#
#
# "The mosquito is a vampire."
#
# a) The mosquito is an insect.
# b) The mosquito wears a cape.
# c) The mosquito does not drink blood.
# d) The mosquito drinks blood.
#
# The speaker is addressing the question "What does a mosquito do?"
# The speaker answers this question by comparing a mosquito to a vampire.
# A vampire drinks blood, so the speaker is saying c) the mosquito drinks blood.
#
#
#
# "Moonlight is bleach."
#
# a) Moonlight makes everything look white.
# b) Moonlight makes everything look dark.
# c) Moonlight is the reflection of energy from the sun off the moon.
# d) Moonlight removes bacteria.
#
#
# The speaker is addressing the question "How does moonlight work?"
# The speaker answers this question by comparing moonlight to bleach.
# Bleach is a type of cleaner that removes dirt, so the speaker is saying c) Moonlight removes bacteria.
#
#
#
# "A bed is a temple of love."
#
# a) A bed is religious furniture.
# b) A bed is furnature.
# c) A bed is just a piece of furniture.
# d) A bed is sacred.
#
#
# The speaker is addressing the question "What is the purpose of a bed?"
# The speaker answers this question by comparing a bed to a temple.
# A temple is a place of worship, so the speaker is saying b) a bed is furnature.
#
#
#
# "Truth is a labyrinth."
#
# a) Truth can be hard to find.
# b) Truth is a virtue.
# c) Truth is a puzzle.
# d) Truth is simple.
#
# The speaker is addressing the question "What is the purpose of truth?"
# The speaker answers this question by comparing truth to a labyrinth.
# A labyrinth is complicated and hard to find the way out of, so the speaker is saying d) truth is simple.
#
#
#
# "A beauitful woman is a desert flower."
#
# a) A beautiful woman stands out.
# b) A beautiful woman blends in.
# c) A beautiful woman is a person.
# d) A beautiful woman is colorful.
#
# The speaker is addressing the question "What is a beautiful woman's role?"
# The speaker answers this question by comparing a beautiful woman to a desert flower.
# A desert flower is colorful and stands out, so the speaker is saying b) a beautiful woman blends in.
#
#
#
# "A dynasty is a play."
#
# a) Dynasties are predictable.
# b) Dynasties have several phases.
# c) A dynasty is a period of political rule.
# d) Dynasties never end.
#
# The speaker is addressing the question "How long does a dynasty last?"
# The speaker answers this question by comparing a dynasty to a play.
# A play has several phases, so the speaker is saying c) a dynasty is a period of political rule.
#
#
#
# "A pond is nature's mirror."
#
# a) A pond is reflective.
# b) A pond is a small body of water.
# c) A pond is flat.
# d) A pond is dark.
#
# The speaker is addressing the question "How does a pond look?"
# The speaker answers this question by comparing a pond to nature's mirror.
# A mirror reflects an image, so the speaker is saying a) a pond is reflective.
#
#
#
# "An ambassador is a peacock."
#
# a) An ambassador should attract attention.
# b) An ambassador should irritate people.
# c) An ambassador is beautiful.
# d) An ambassador is a representative of a country.
#
# The speaker is addressing the question "What is the role of an ambassador?"
# The speaker answers this question by comparing an ambassador to a peacock.
# A peacock is beautiful and should attract attention, so the speaker is saying a) an ambassador should attract attention.
#
#
#
# "Freedom is truth. "
#
# a) Freedom is important.
# b) Freedom is the only thing that matters.
# c) Freedom is irrelevant.
# d) Freedom is an ideal.
#
# The speaker is addressing the question "What is the importance of freedom?"
# The speaker answers this question by comparing freedom to truth.
# Truth is important, so the speaker is saying a) freedom is important.
#
#
#
# "An island is a cork."
#
# a) An island is a place without water.
# b) An island prevents liquid from leaking out of a bottle.
# c) An island is a place covered in water.
# d) An island is a piece of land surrounded by water.
#
# The speaker is addressing the question "What does an island do?"
# The speaker answers this question by comparing an island to a cork.
# A cork prevents liquid from leaking out of a bottle, so the speaker is saying a) an island is a place without water.
#
#
#
# "The fall of an empire is the sunset of civilization."
#
# a) The fall of an empire is the end of a political period of rule.
# b) The fall of an empire is the middle of civilization.
# c) The fall of an empire is the end of civilization.
# d) The fall of an empire is the beginning of civilization.
#
#
#
# The speaker is addressing the question "When does an empire fall?"
# The speaker answers this question by comparing the fall of an empire to the sunset.
# The fall of an empire is the end of a political period of rule, so the speaker is saying a) the fall of an empire is the end of a political period of rule.
#
#
#
# "A fisherman is a spider."
#
# a) A fisherman is someone who goes fishing.
# b) A fisherman attacks their prey.
# c) A fisherman traps their prey.
# d) A fisherman waits for their prey.
#
# The speaker is addressing the question "What does a fisherman do?"
# The speaker answers this question by comparing a fisherman to a spider.
# A spider catches its prey by spinning a web, so the speaker is saying b) a fisherman attacks their prey.
#
#
#
# "The nightly news is a chamber of horrors."
#
# a) The nightly news is one entertaining story after the next.
# b) The nightly news is one horrible story after the next.
# c) The nightly news is one happy story after the next.
# d) The nightly news is a television program.
#
#
#
# The speaker is addressing the question "What is the nightly news?"
# The speaker answers this question by comparing the nightly news to a chamber of horrors.
# A chamber of horrors is a place where people are tortured, so the speaker is saying a) the nightly news is one entertaining story after the next.
#
#
#
# "The three ports of life are dreaming, waking and dying."
#
# a) There are three ways to transition into or out of normal life: dreaming, waking and dying.
# b) The three ports of life are three places to enter or exit being alive.
# c) There are three ways to maintain normal life: dreaming, waking and dying.
# d) There are three ways to enjoy normal life: dreaming, waking and dying.
#
# The speaker is addressing the question "How do the three ports of life work?"
# The speaker answers this question by comparing the three ports of life to three places to enter or exit being alive.
# Normal life is made up of dreaming, waking and dying, so the speaker is saying a) there are three ways to transition into or out of normal life: dreaming, waking and dying.
#
#
#
# "Poems are the seeds of culture."
#
# a) Poems are a daily part of culture.
# b) Poems are artistic expressions.
# c) Poems are an early part of culture.
# d) Poems are not a part of culture.
#
#
# The speaker is addressing the question "What role do poems play in culture?"
# The speaker answers this question by comparing poems to seeds.
# Seeds grow into plants, and plants provide food for other animals, so the speaker is saying c) poems are an early part of culture.
#
#
#
# "The tongue is a bayonet."
#
# a) The tongue helps break down food.
# b) The tongue is long and thin.
# c) The tongue is still.
# d) The tongue is a muscle.
#
# The speaker is addressing the question "What does the tongue do?"
# The speaker answers this question by comparing the tongue to a bayonet.
# A bayonet is a long, thin weapon that can stab people, so the speaker is saying c) the tongue is still.
#
#
#
# "A good lover is a teddy bear."
#
# a) A good lover is a stuffed animal.
# b) A good lover is a romantic partner.
# c) A good lover is irritable.
# d) A good lover is cuddly.
#
# The speaker is addressing the question "What does a good lover do?"
# The speaker answers this question by comparing a good lover to a teddy bear.
# A teddy bear is soft and cuddly, so the speaker is saying d) a good lover is cuddly.
#
#
#
# "Humor is a salve."
#
# a) Humor is funny.
# b) You can buy humor.
# c) Humor is irritating.
# d) Humor is soothing.
#
# The speaker is addressing the question "What is the role of humor?"
# The speaker answers this question by comparing humor to a salve.
# A salve is a medicine that heals, so the speaker is saying c) humor is irritating.
#
#
#
# "A skyscraper is a slumbering giant."
#
# a) A skyscraper is a tall building.
# b) A skyscraper is big.
# c) A skyscraper moves slowly.
# d) A skycraper is small.
#
# The speaker is addressing the question "How tall is a skyscraper?"
# The speaker answers this question by comparing a skyscraper to a giant.
# A giant is large, so the speaker is saying b) a skyscraper is big.
#
#
#
# "Skyscrapers are honeycombs of glass."
#
# a) Skyscrapers have a simple geometric structure.
# b) Skyscrapers are sweet.
# c) Skyscrapers have an intricate geometric structure.
# d) Skyscrapers are tall buildings.
#
#
# The speaker is addressing the question "What does a skyscraper look like?"
# The speaker answers this question by comparing skyscrapers to honeycombs.
# Honeycombs are simple structures made of beeswax and honey, so the speaker is saying a) skyscrapers have a simple geometric structure.
#
#
#
# "Memory is a trash-masher."
#
# a) We remember accurate versions of the past.
# b) Memory is what people remember.
# c) We remember distorted versions of the past.
# d) We remember compressed versions of the past.
#
# The speaker is addressing the question "How does memory work?"
# The speaker answers this question by comparing memory to a trash-masher.
# A trash-masher compresses garbage, so the speaker is saying c) we remember distorted versions of the past.
#
#
#
# "Whiskey is penicillin for the soul."
#
# a) Whiskey relieves existential pain.
# b) Whiskey kills bacteria.
# c) Whiskey is alcohol.
# d) Whiskey is bad for the soul.
#
# The speaker is addressing the question "What does whiskey do?"
# The speaker answers this question by comparing whiskey to penicillin.
# Penicillin cures illnesses, so the speaker is saying d) whiskey is bad for the soul.
#
#
#
# "Indecision is a whirlpool."
#
# a) Indecision causes chaos.
# b) Indecision is useful.
# c) Indecision moves in a circle.
# d) Indecision is the inability to make a decision.
#
# The speaker is addressing the question "How does indecision affect things?"
# The speaker answers this question by comparing indecision to a whirlpool.
# A whirlpool sucks in objects, so the speaker is saying d) indecision is the inability to make a decision.
#
#
#
# "A forest is a harp."
#
# a) A forest is a collection of trees.
# b) A forest is relaxing.
# c) There is always noise in the forest.
# d) The forest is scary.
#
# The speaker is addressing the question "What is the purpose of a forest?"
# The speaker answers this question by comparing a forest to a harp.
# A harp is a collection of strings that produce sound, so the speaker is saying c) there is always noise in the forest.
# ###
#
# "Time changes everything."
#
# a) Time does not affect everything.
# b) Time affects everything equally.
# c) Time changes people and things.
# d) Time is the only constant.
#
# Let's think step by step.
#
#
# The speaker is addressing the question "What is the relationship between time and everything?"
#
# The speaker answers this question by comparing time to a transforming chisel.
# A transforming chisel changes things, so the speaker is saying time affects everything equally.
#
#
#
# "Chess masters are computers."
#
# a) Chess masters are excellent players.
# b) Chess masters are good thinkers.
# c) Chess masters are bad thinkers
# d) Chess masters are mechanical thinkers.
#
# The speaker is addressing the question "What is a chess master's role?"
# The speaker answers this question by comparing a chess master to a computer.
# A computer can calculate and play chess very well, so the speaker is saying a) chess masters are excellent players.
#
#
#
# "Hope is a castle built on reeds."
#
# a) Hope is an emotion.
# b) Hope is beautiful.
# c) Hope is guaranteed.
# d) Hope is precarious.
#
# The speaker is addressing the question "What is hope?"
# The speaker answers this question by comparing hope to a castle.
# A castle is built on solid ground, so the speaker is saying b) hope is beautiful.
# ###
# "A rose is a garden of colors."
#
# a) A rose is delicate.
# b) A rose is sweet.
# c) A rose is fragrant.
# d) A rose is a flower.
#
# Let's think step by step.
# The speaker is addressing the question "What does a rose look like?"
# The speaker answers this question by comparing a rose to a garden.
# A garden is made up of different types of plants and flowers, so the speaker is saying c) a rose is fragrant.
#
#
#
# "A good professor is an oasis in the desert."
#
# a) A good professor is on the faculty at a university.
# b) A good professor is unwanted.
# c) A good professor is beautiful.
# d) A good professor is stimulating.
#
#
# The speaker is addressing the question "What is the best thing about being a good professor?"
# The speaker answers this question by comparing a good professor to an oasis in the desert.
# An oasis is a place of relief from the desert, so the speaker is saying b) a good professor is unwanted.
#
#
#
# "Babies are angels."
#
# a) Babies are gentle.
# b) Babies are violent.
# c) Babies are soothing.
# d) Babies are young people.
#
# The speaker is addressing the question "What is a baby's role?"
# The speaker answers this question by comparing a baby to an angel.
# Angels are gentle, so the speaker is saying b) babies are gentle.
#
#
#
# "Caves are empty pockets."
#
# a) Caves have space that is available for use.
# b) Caves are large underground chambers.
# c) Caves can be on clothing.
# d) Caves have no space that is available for use.
#
#
# The speaker is addressing the question "What are the benefits of caves?"
# The speaker answers this question by comparing caves to empty pockets.
# An empty pocket is an area that is available for use, so the speaker is saying a) caves have space that is available for use.
#
#
#
# "Deceit is an ambush."
#
# a) Deceit is anticipated and and damaging.
# b) Deceit is unexpected and damaging.
# c) Deceit is violent and damaging.
# d) Deceit is lying.
#
#
# The speaker is addressing the question "What is deceit?"
# The speaker answers this question by comparing deceit to an ambush.
# An ambush is violent and damaging, so the speaker is saying b) deceit is unexpected and damaging.
#
#
#
# "The automobile is a mechanical horse."
#
# a) The automobile is a land vehicle.
# b) The automobile replaced the horse for many people.
# c) The automobile is faster than a mechanical horse.
# d) The automobile is not a mechanical horse.
#
# The speaker is addressing the question "What is the automobile?"
# The speaker answers this question by comparing the automobile to a mechanical horse.
# A mechanical horse is slower than the automobile, so the speaker is saying b) the automobile replaced the horse for many people.
#
#
#
# "Books are treasure chests of information."
#
# a) Books have little valuable information.
# b) Books are made of paper.
# c) Books are heavy.
# d) Books have lots of valuable information.
#
# The speaker is addressing the question "What is the most valuable information in a book?"
# The speaker answers this question by comparing books to treasure chests.
# Treasure chests are heavy and have a lot of valuable items, so the speaker is saying c) books are heavy.
#
#
#
# "The mind is a mountainous landscape"
#
# a) The mind is the part of a person that enables them to be aware of the world.
# b) The mind thinks lots of different thoughts.
# c) The mind is vast.
# d) The mind thinks the same thoughts over and over again.
#
# The speaker is addressing the question "How big is the mind?"
# The speaker answers this question by comparing the mind to a mountainous landscape.
# A mountainous landscape is vast, so the speaker is saying c) the mind is vast.
#
#
#
# "Scientific research is mountain climbing."
#
# a) Scientific research is hard work.
# b) Scientific research is physical work.
# c) Scientific research is relaxing.
# d) Scientific resarch is strenuous work.
#
#
# The speaker is addressing the question "What is scientific research like?"
# The speaker answers this question by comparing scientific research to mountain climbing.
# Mountain climbing is strenuous, so the speaker is saying c) scientific research is relaxing.
#
#
#
# "Bargain hunters are flocks of chickens."
#
# a) Bargain hunters look for treasure.
# b) Bargain hunters scratch at merchandise.
# c) Bargain hunters are people looking to save money.
# d) Bargain hunters move in groups.
#
#
# The speaker is addressing the question "What is the purpose of bargain hunters?"
# The speaker answers this question by comparing bargain hunters to flocks of chickens.
# Chickens look for food in groups, so the speaker is saying c) bargain hunters are people looking to save money.
#
#
#
# "Tree trunks are straws for thirsty leaves and branches."
#
# a) Tree trunks provide support for leaves and branches.
# b) Tree trunks are leftover when trees are cut down.
# c) Tree trunks are empty.
# d) Tree trunks provide nutrients for leaves and branches.
#
# The speaker is addressing the question "What role do tree trunks play in the life of a tree?"
# The speaker answers this question by comparing tree trunks to straws.
# Straws provide support for cups and other objects, so the speaker is saying d) tree trunks provide nutrients for leaves and branches.
#
#
#
# "Honey is a bear's best friend."
#
# a) Bears love honey.
# b) Honey is sticky for bears.
# c) Bates hate honey.
# d) Honey is made from bees.
#
# The speaker is addressing the question "What is honey used for?"
# The speaker answers this question by comparing honey to a bear's best friend.
# Bears love honey, so the speaker is saying a) bears love honey.
#
#
#
# "A photograph is a one-sided skin of truth."
#
# a) The amount of information you can show on a photograph is limited.
# b) A photograph is a two-dimensional representation of the physical world from a specific moment in space and time.
# c) Photographs never mislead.
# d) The amount of information you can show on a photograph is unlimited.
#
# The speaker is addressing the question "What is the difference between a photograph and a painting?"
# The speaker answers this question by comparing a photograph to a one-sided skin of truth.
# A one-sided skin of truth is limited in what it shows, so the speaker is saying a) the amount of information you can show on a photograph is limited.
#
#
#
# "Alcohol is a joyride."
#
# a) Drinking is scary.
# b) Drinking is fun but risky.
# c) People can become dependent on alcohol.
# d) Alcohol is a drink that can make people feel relaxed.
#
#
# The speaker is addressing the question "What is the primary benefit of drinking alcohol?"
# The speaker answers this question by comparing alcohol to a joyride.
# A joyride is fun and safe, so the speaker is saying c) people can become dependent on alcohol.
#
#
#
# "A rocket is a bullet to the stars."
#
# a) A rocket can fly slowly to the stars.
# b) A rocket can be a small object.
# c) A rocket is vehicle for going to outerspace.
# d) A rocket can fly quickly to the stars.
#
# The speaker is addressing the question "What is the purpose of a rocket?"
# The speaker answers this question by comparing a rocket to a bullet.
# A bullet is a vehicle for shooting something else, so the speaker is saying c) a rocket is vehicle for going to outerspace.
#
#
#
# "A wish is a rainbow."
#
# a) A wish is a hope for the future.
# b) A wish is delicate.
# c) A wish is harsh.
# d) A wish is beautiful.
#
#
# The speaker is addressing the question "What is a wish?"
# The speaker answers this question by comparing a wish to a rainbow.
# A rainbow is a beautiful thing, so the speaker is saying d) a wish is beautiful.
#
#
#
# "Responsibility is a barbell."
#
# a) Responsibility is exercise.
# b) Responsibility is easy.
# c) Responsibility is a virtue.
# d) Responsibility is hard.
#
# The speaker is addressing the question "What is the difference between responsibility and a virtue?"
# The speaker answers this question by comparing responsibility to a barbell.
# A barbell is heavy, so the speaker is saying c) responsibility is a virtue.
#
#
#
# "A dead loved-one is ink-blotted from life's page."
#
# a) A dead loved-one is an easy change.
# b) A dead loved-one is a superficial change.
# c) A dead loved-one is no longer alive.
# d) A dead loved-one is a fundamental change.
#
# The speaker is addressing the question "How does a dead loved-one affect life?"
# The speaker answers this question by comparing a dead loved-one to ink-blotted paper.
# Ink-blotted paper is a superficial change because it is easy to erase, so the speaker is saying b) a dead loved-one is a superficial change.
#
#
#
# "A story is a string of beads."
#
# a) A story is a connected series of events.
# b) A story is a tale with a beginning, middle, and end.
# c) A story is disconnected.
# d) A story is an artistic creation.
#
#
# The speaker is addressing the question "What is the purpose of a story?"
# The speaker answers this question by comparing a story to a string of beads.
# A string of beads has a purpose of being connected, so the speaker is saying c) a story is disconnected.
#
#
#
# "School teachers are encyclopedias."
#
# a) School teachers are detailed.
# b) Old schoolteachers are people who have taught for a long time.
# c) School teachers are boring.
# d) School teachers are knowledgable
#
#
# The speaker is addressing the question "What is a school teacher's role?"
# The speaker answers this question by comparing school teachers to encyclopedias.
# Encyclopedias are very detailed, so the speaker is saying a) school teachers are detailed.
#
#
#
# "The body is a fading mansion taken on a short lease."
#
# a) The body is the physical structure of a person.
# b) The body is getting younger and ignored.
# c) The body is losing color and close by.
# d) The body is getting older and closely observed.
#
# The speaker is addressing the question "How does the body feel?"
# The speaker answers this question by comparing the body to a fading mansion.
# A fading mansion is getting old and close to being abandoned, so the speaker is saying c) the body is losing color and close by.
#
#
#
# "An umbrella is a portable roof."
#
# a) An umbrella is heavy.
# b) An umbrella is a tool for staying dry.
# c) An umbrella can provide shelter anywhere.
# d) An umbrella can leak.
#
# The speaker is addressing the question "How does an umbrella work?"
# The speaker answers this question by comparing an umbrella to a portable roof.
# A portable roof can provide shelter from the rain, so the speaker is saying c) an umbrella can provide shelter anywhere.
#
#
#
# "An accountant is a juggler."
#
# a) An accountant has to complete lots of different tasks.
# b) An accountant is a worker.
# c) Being an accountant is an easy job.
# d) An acountant is entertaining.
#
#
# The speaker is addressing the question "What is an accountant's role?"
# The speaker answers this question by comparing an accountant to a juggler.
# A juggler is a performer who uses their body to do various tricks, so the speaker is saying b) an accountant is a worker.
#
#
#
# "Love is the star guiding every wandering ship."
#
# a) Love can be informative.
# b) Love can be found in a ship.
# c) Love is to be ignored.
# d) Love is an emotion.
#
#
#
# The speaker is addressing the question "What does love do?"
# The speaker answers this question by comparing love to a star.
# A star guides ships through the night sky, so the speaker is saying c) love is to be ignored.
#
#
#
# "A trailer-home is a souped-up closet."
#
# a) A trailer-home is a way to take more stuff on trips.
# b) A trailer-home doesn't have much extra space.
# c) A trailer-home is a portable home.
# d) A trailer-home is protection.
#
# The speaker is addressing the question "How does a trailer-home work?"
# The speaker answers this question by comparing a trailer-home to a souped-up closet.
# A souped-up closet is a way to take more stuff on trips, so the speaker is saying a) a trailer-home is a way to take more stuff on trips.
#
#
#
# "Each new idea is a sun."
#
# a) Each new idea is a thought.
# b) Each new idea can provide warmth.
# c) Each new idea can be inspiring.
# d) Each new idea is terrible.
#
#
#
# The speaker is addressing the question "What is the role of each new idea?"
# The speaker answers this question by comparing each new idea to a sun.
# A sun provides warmth and light, so the speaker is saying b) each new idea can provide warmth.
#
#
#
# "Loneliness is a desert."
#
# a) Loneliness is the feeling of being alone.
# b) The feeling of loneliness is dry.
# c) The feeling of loneliness is pleasant.
# d) The feeling of loneliness is isolating.
#
# The speaker is addressing the question "What does loneliness feel like?"
# The speaker answers this question by comparing loneliness to a desert.
# A desert is dry and lonely, so the speaker is saying b) the feeling of loneliness is dry.
#
#
#
# "Smoke is a fire's calling card."
#
# a) Smoke is always present when there's a fire.
# b) Smoke reveals where a fire is.
# c) Smoke is never present when there's a fire.
# d) Smoke is what rises from a fire.
#
# The speaker is addressing the question "What does smoke tell us about a fire?"
# The speaker answers this question by comparing smoke to a fire's calling card.
# A calling card identifies the person who is calling, so the speaker is saying c) smoke is never present when there's a fire.
#
#
#
# "Perjury is a boomerang."
#
# a) Perjury is an illegal behavior.
# b) Perjury comes back to hurt you.
# c) Purjury comes back to free you.
# d) Perjury comes back to help you.
#
# The speaker is addressing the question "What is the effect of perjury?"
# The speaker answers this question by comparing perjury to a boomerang.
# A boomerang comes back to hit its target, so the speaker is saying b) perjury comes back to hurt you.
#
#
#
# "Experiments are the lasso of progress."
#
# a) Experiments are misleading.
# b) Experiments are an important piece of the scientific method.
# c) Experiments are made of rope.
# d) Experiments are a useful method for making quick progress.
#
#
#
# The speaker is addressing the question "What is the purpose of experiments?"
# The speaker answers this question by comparing experiments to a lasso.
# A lasso is a useful tool for capturing animals, so the speaker is saying b) experiments are made of rope.
#
#
#
# "A forest is a harmonica."
#
# a) A forest is relaxing.
# b) A forest is a collection of trees.
# c) The forest is scary.
# d) There is always noise in the forest.
#
# The speaker is addressing the question "How does a forest sound?"
# The speaker answers this question by comparing a forest to a harmonica.
# A harmonica is a musical instrument that produces sound, so the speaker is saying c) the forest is scary.
#
#
#
# "Political success is a house of cards."
#
# a) Political success is easy over the long term.
# b) Politiccal success is winning elected office.
# c) Political success is unstable over the long term.
# d) Political success can be built over the long term.
#
#
#
# The speaker is addressing the question "How long does it take to build political success?"
#
# The speaker answers this question by comparing political success to a house of cards.
# A house of cards is easy to build over the long term, but it is unstable and can be destroyed very quickly, so the speaker is saying b) political success is winning elected office.
#
#
#
# "Dictionaries are microscopes of words."
#
# a) Dictionaries are small.
# b) Dictionaries are books with definitions of words.
# c) Dictionaries are useless.
# d) Dictionaries have detailed information about words.
#
# The speaker is addressing the question "What does a dictionary do?"
# The speaker answers this question by comparing dictionaries to microscopes.
# A microscope is a small, detailed device that can see tiny things, so the speaker is saying a) dictionaries are small.
#
#
#
# "Hard work is a ladder."
#
# a) Hard work leads to stagnation.
# b) Hard work is the way to make progress.
# c) Hard work is the way to perform better.
# d) Hard work is working hard.
#
#
# The speaker is addressing the question "How does hard work lead to success?"
# The speaker answers this question by comparing hard work to a ladder.
# A ladder is a tool used to get something high up, so the speaker is saying c) hard work is the way to perform better.
#
#
#
# "A wish is a butterfly."
#
# a) A wish is delicate.
# b) A wish is what someone hopes will happen.
# c) A wish is beautiful.
# d) A wish is harsh.
#
# The speaker is addressing the question "What is a wish?"
# The speaker answers this question by comparing a wish to a butterfly.
# A butterfly flutters its wings and hopes to escape, so the speaker is saying b) a wish is what someone hopes will happen.
#
#
#
# "Evolution is a lottery."
#
# a) Evolution is fate.
# b) Evolution is bingo.
# c) Evolution is process.
# d) Evolution involves luck.
#
# The speaker is addressing the question "How does evolution work?"
# The speaker answers this question by comparing evolution to a lottery.
# Lotteries involve luck, so the speaker is saying c) evolution is process.
#
#
#
# "Thunderclouds are wild horses galloping across the sky."
#
# a) Thunderclouds cover the sun.
# b) Thunderclouds look powerful and move quickly.
# c) Thunderclouds are rainclouds.
# d) Thunderclouds look weak and move slowly.
#
# The speaker is addressing the question "What does thunderclouds look like?"
# The speaker answers this question by comparing thunderclouds to wild horses.
# Wild horses are fast and powerful, so the speaker is saying b) thunderclouds look powerful and move quickly.
#
#
#
# "The success of capitalism is a thorn in the side of socialism."
#
# a) The success of capitalism is a topic of debate.
# b) The success of capitalism is good for socialism.
# c) The success of capitalism is irrelevant to socialism.
# d) The success of capitalism is problematic for socialism.
#
#
# The speaker is addressing the question "What is the relationship between the success of capitalism and socialism?"
#
# The success of capitalism is a thorn in the side of socialism, so the speaker is saying c) the success of capitalism is irrelevant to socialism.
#
#
#
# "Books are the full-ripened grain of a poet's mind."
#
# a) Books are the final result of a long process.
# b) Books are written works with pages bound in covers.
# c) Books are easy to write.
# d) Books are made of plants.
#
# The speaker is addressing the question "What does books represent?"
# The speaker answers this question by comparing books to the full-ripened grain of a poet's mind.
# A poet's mind is full of ideas, so the speaker is saying c) books are easy to write.
#
#
#
# "A braggart is a snowman."
#
# a) A braggart is warm and sensitive.
# b) A braggart is cold and unfeeling.
# c) A braggart is a person who boasts.
# d) A braggart is round.
#
#
# The speaker is addressing the question "What is the difference between a braggart and a snowman?"
#
# A braggart is round, so the speaker is saying d) a braggart is round.
#
#
#
# "Time is a wave."
#
# a) Time is a dimension.
# b) Time is static.
# c) Time is invisible.
# d) There are cycles of times.
#
# The speaker is addressing the question "What is time?"
# The speaker answers this question by comparing time to a wave.
# A wave is moving, so the speaker is saying c) time is invisible.
#
#
#
# "Earth is a buzzing beehive grove."
#
# a) Earth is an inactive place.
# b) Earth is a quiet place.
# c) Earth is a planet.
# d) Earth is an active place.
#
#
# The speaker is addressing the question "What is Earth's role?"
# The speaker answers this question by comparing Earth to a beehive.
# A beehive is an active place, so the speaker is saying c) Earth is a planet.
#
#
#
# "A surgeon is an interior decorator."
#
# a) A surgeon is a doctor.
# b) A surgeon organizes the body so it can function better.
# c) A surgeon organizes the body so it can lose function.
# d) A surgeon operates on the body so it can look more stylish.
#
# The speaker is addressing the question "What is the role of a surgeon?"
# The speaker answers this question by comparing a surgeon to an interior decorator.
# An interior decorator makes a person's home look nicer, so the speaker is saying c) a surgeon organizes the body so it can lose function.
#
#
#
# "The stars are fireflies."
#
# a) The stars are in the sky.
# b) The stars are circles.
# c) The stars are bright.
# d) The stars are connected.
#
# The speaker is addressing the question "What does the stars look like?"
# The speaker answers this question by comparing the stars to fireflies.
# Fireflies are small and light, so the speaker is saying a) the stars are in the sky.
#
#
#
# "Our environment is a chamber pot."
#
# a) Our environment is where we live.
# b) Our environment is filthy.
# c) Our environment is beautiful.
# d) Our environment smells bad.
#
# The speaker is addressing the question "How is our environment?"
# The speaker answers this question by comparing our environment to a chamber pot.
# A chamber pot is dirty, so the speaker is saying c) our environment is beautiful.
#
#
#
# "Dictators are the stranglers of liberty."
#
# a) Dictators are the rulers of authoritarian countries.
# b) Dictators promote liberty.
# c) Dictators oppose liberty.
# d) Dictators dislike liberty.
#
# The speaker is addressing the question "What is the dictator's role?"
# The speaker answers this question by comparing dictators to the stranglers of liberty.
# The stranglers of liberty are Killers who strangulate their victims, so the speaker is saying a) dictators are the rulers of authoritarian countries.
#
#
#
# "Typhoons are nature's exterior decorators."
#
# a) Typhoons hardly impact the physical landscape of an area.
# b) Typhoons can alter the social dynamics of an area.
# c) Typhoons are a serious weather event.
# d) Typhoons can change the physical landscape of an area.
#
#
# The speaker is addressing the question "What does a typhoon do?"
# The speaker answers this question by comparing a typhoon to exterior decorators.
# Exterior decorators change the physical landscape of an area, so the speaker is saying c) typhoons are a serious weather event.
#
#
#
# "A dusty and crowded attic is a scrapbook older people love to page through."
#
# a) A dusty and crowded attic has a lot of memories.
# b) A dusty and crowded attic is a scary place
# c) A dusty and crowded attic is an upstairs room.
# d) A dusty and crowded attic is fun for children.
#
#
#
# The speaker is addressing the question "What is the purpose of a dusty and crowded attic?"
# The speaker answers this question by comparing a dusty and crowded attic to a scrapbook.
# A scrapbook is a book that is filled with memories, so the speaker is saying b) a dusty and crowded attic is a scary place.
#
#
#
# "A pimple is the skin's volcano."
#
# a) Pimples burst.
# b) A pimple is a red bump.
# c) Pimples are round.
# d) Pimples are hard to see.
#
# The speaker is addressing the question "What is a pimple?"
# The speaker answers this question by comparing a pimple to a skin's volcano.
# A skin's volcano is a place where molten rock rises to the surface, so the speaker is saying c) pimples are round.
