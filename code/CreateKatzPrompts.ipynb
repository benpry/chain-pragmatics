# %%
import pandas as pd
from pyprojroot import here

# %%
df_prompts = pd.read_csv(here("data/katz-corpus/katz-corpus-train.csv"))

# %%
df_prompts.loc[24]["Good (4)"]
# Out:
# "Terrorists are people who seek to use violence among people who don't wish to use violence."

# %%
df_prompts[["Statement", "Good (4)", "values"]]
# Out:
#                                             Statement  \
# 0                   An idea is a kettle on the stove.
# 1                                  Happiness is gold.
# 2                          A lottery is a rich uncle.
# 3                             A storm is a coffeepot.
# 4                               The wind is an arrow.
# 5                      Time is a transforming chisel.
# 6                       Criticism is a branding iron.
# 7                              An ant is a bulldozer.
# 8                             The wind is a wrestler.
# 9                                Time is a physician.
# 10                       Age is an altar of memories.
# 11                              Genes are blueprints.
# 12                         History is an alarm clock.
# 13                       A bagpipe is a newborn baby.
# 14                   Mankind is a prisoner of wishes.
# 15                               Power is penicillin.
# ...

# %%
# QUD rationales
qud_rationales = [
    'The speaker is addressing the question "How long does it take for an idea to be ready?"\nA kettle on the stove takes a long time to be ready\nSo the speaker is saying that it takes time for an idea to be ready.\nTherefore, the answer is a).',
    'The speaker is addressing the question "How valuable is happiness?"\nGold is very valuable.\nSo the speaker is saying that happiness is valuable.\nTherefore, the answer is d).',
    'The speaker is addressing the question "How accessible is wealth from a lottery?"\nA rich uncle might provide easily accessible wealth, but also might not.\nSo the speaker is saying that a lottery is wealth that seems accessible but may not be.\nTherefore, the answer is d).',
    'The speaker is addressing the question "How dark is a storm?"\nA coffeepot is very dark.\n So the speaker is saying that a storm is dark.\nTherefore, the answer is b).',
    'The speaker is addressing the question "How does the wind travel?"\nAn arrow travels straight and fast.\nSo the speaker is saying the wind goes straight and fast.\nTherefore, the answer is a).',
    'The speaker is addressing the question "How does time affect things?"\nA transforming chisel changes things.\nSo the speaker is saying that things change over time.\nTherefore, the answer is b).',
    'The speaker is addressing the question "How does criticism feel?"\nA branding iron is very painful.\nSo the speaker is saying that criticism is painful.\nTherefore, the answer is d).',
    'The speaker is addressing the question "How much dirt can an ant move?"\nA bulldozer can move a lot of dirt\nSo the speaker is saying that an ant can move a lot of dirt.\nTherefore, the answer is d).',
    'The speaker is addressing the question "How strong and agile is the wind?"\nA wrestler is strong and agile\nSo the speaker is saying that the wind is strong and agile.\nTherefore, the answer is d).',
    'The speaker is addressing the question "How does time affect sicknesses and injuries?"\nA physician heals wounds and sicknesses.\nSo the speaker is saying that many ailments like sickness and broken bones heal with time.\nTherefore, the answer is d).',
    'The speaker is addressing the question "How does age affect memories?"\nAn altar of memories has many memories.\nSo the speaker is saying that older people have more memories.\nTherefore, the answer is d)',
    'The speaker is addressing the question "What do genes do?"\nBlueprints are instructions for building.\nSo the speaker is saying that genes are instructions.\nTherefore, the answer is a).',
    'The speaker is addressing the question "How does history affect us?"\nAlarm clocks motivate people to start the day.\nSo the speaker is saying that history is motivation.\nTherefore, the answer is b).',
    'The speaker is addressing the question "How does a bagpipe sound?"\nNewborn babies are loud.\nSo the speaker is saying that a bagpipe is loud.\nTherefore, the answer is c).',
    'The speaker is addressing the question "How much control do people have over what they want?"\nA prisoner of wishes does not have control over their wishes\nSo the speaker is saying that people don\'t have control over what they want\nTherefore, the answer is a).',
    'The speaker is addressing the question "What can power do?"\nPenicillin is a strong antibiotic that can solve medical problems.\nSo the speaker is saying that power can resolve problems.\nTherefore, the answer is b).',
    'The speaker is addressing the question "What is people\'s relationship to their desires?"\nWandering outlaws of dark minds often do bad things.\nSo the speaker is saying that people can\'t help themselves from wanting to do bad things sometimes.\nTherefore, the answer is c).',
    'The speaker is addressing the question "What do mosquitoes do?"\nArrows fly through the air and can puncture people\'s skin.\nSo the speaker is saying that mosquitoes fly through the air and into people.\nTherefore, the answer is c).',
    'The speaker is addressing the question "What role to billboards play on the highway?"\nThe yellow pages provide readers with information about companies.\nSo the speaker is saying that billboards provide information about companies.\nTherefore, the answer is a).',
    'The speaker is addressing the quesiton "What is silence like?"\nA black cavern is mysterious as people cannot see inside.\nSo the speaker is saying that silence is mysterious.\nTherefore, the answer is c).',
    'The speaker is addressing the question "How important is a person\'s life on the scale of the earth?"\nA worm is small compared to the carcass it feeds from.\nSo the author is saying that a person\'s life is small and irrelevant.\nTherefore, the answer is a).',
    'The speaker is addressing the question "What role to craters play on the moon\'s surface?"\nDimples give a person\'s face character.\nSo the speaker is saying that craters give character to the moon\'s surface.\nTherefore, the answer is d).',
    'The speaker is addressing the question "What does silence do?"\nAprons prevent risk to cooks.\nSo the speaker is saying that silence prevents risk.\nTherefore, the answer is b).',
    'The speaker is addressing the question "How does history change over time?"\nA sponge absorbs water.\nSo the speaker is saying that history absorbs people and stories.\nTherefore, the answer is c).',
    'The speaker is addressing the question "What do terrorists seek to do?"\nHawks violently attack fowl, while fowl are mostly passive.\nSo the speaker is saying that terrorists seek to use violence among people who don\'t wish to use violence.\nTherefore, the answer is b).',
    'The speaker is addressing the question "What is the sea captain\'s role on his ship?"\nThe quarterback is in charge of the football team while playing.\nSo the speaker is saying that the sea captain is in charge of his ship.\nTherefore, the answer is b).',
    'The speaker is addressing the question "How do thunderclouds affect the sun?"\nDraperies cover the things they are pulled across.\nSo the speaker is saying that thunderclouds cover the sun.\nTherefore, the answer is c).',
    'The speaker is addressing the question "What does the spy satellite do four our nation\'s security?\nShepherds monitor their herds to make sure they are secure.\nSo the speaker is saying that the spy satellite helps monitor our nation\'s security.\nTherefore, the answer is a).',
    'The speaker is addressing the question "How big is the desert?"\nA sea is vast.\nSo the speaker is saying that a desert is vast.\nTherefore, the answer is a).',
    'The speaker is addressing the question "How predictable is nature?"\nA laboratory is not predictable.\nSo the speaker is saying that nature is an unpredictable place.\nTherefore, the answer is a).'
]

# %%
# similarity-based rationales
similarity_rationales = [
    "Kettles on the stove take a long time to be ready.\nIdeas can also take a long time to be ready.\nSo the speaker is saying that it takes time for an idea to be ready.\nTherefore, the answer is a).",
    "Gold is valuable.\nHappiness can also be valuable.\nSo the speaker is saying that happiness is valuable.\nTherefore, the answer is d).",
    "A rich uncle provides wealth that seems accessible, but may not actually be.\nA lottery promises to provide wealth, but winning is very unlikely.\nSo the speaker is saying that a lottery is wealth that seems accessible but may not be.\nTherefore, the answer is d).",
    "A coffeepot is dark.\nStorms can also be dark.\nSo the speaker is saying that a storm is dark.\nTherefore, the answer is b).",
    "An arrow travels straight and fast.\nThe wind can also travel straight and fast.\nSo the speaker is saying that the wind goes straight and fast.\nTherefore, the answer is a).",
    "A transforming chisel changes things when used.\nTime can also cause things to change.\nSo the speaker is saying that things change over time.\nTherefore, the answer is b).",
    "Branding irons are extremely painful.\nCriticism can also be painful.\nSo the speaker is saying that criticism is painful.\nTherefore, the answer is d).",
    "A bulldozer moves a lot of dirt.\nAnts can also move dirt.\nSo the speaker is saying that an ant can move a lot of dirt.\nTherefore, the answer is d).",
    "A wrestler is strong and agile.\nThe wind can also be strong and agile.\nSo the speaker is saying that the wind is strong an agile.\nTherefore, the answer is d).",
    "Physicians heal ailments.\nAilments like sicknesses and broken bones often heal over time.\nSo the speaker is saying that many ailments like sickness and broken bones heal over time.\nTherefore, the answer is d).",
    "An altar of memories has many memories.\nOlder people also have many memories.\nSo the speaker is saying that older people have more memories.\nTherefore, the answer is d).",
    "Blueprints are instructions for how to build something.\nGenes also contain instructions for building living things.\nSo the speaker is saying that genes are instructions.\nTherefore, the answer is a).",
    "Alarm clocks motivate people to get out of bed.\nHistory can also motivate people.\nSo the speaker is saying that history is motivation.\nTherefore, the answer is b).",
    "A newborn baby is loud.\nBagpipes are also loud.\nSo the speaker is saying that a bagpipe is loud.\nTherefore, the answer is c).",
    "A prisoner of wishes has no control over what they want.\nMankind can also struggle with a lack of control over what they want.\nSo the speaker is saying that people don't have control over what they want.\nTherefore, the answer is a).",
    "Penicilin is a strong antibiotic that can solve medical problems.\nPower can also solve many problems.\nSo the speaker is saying that power can resolve problems.\nTherefore, the answer is b).",
    "A wandering outlaw of a dark mind does bad things.\nMan often wants to do bad things.\nSo the speaker is saying that people can't help themselves from wanting to do bad things.\nTherefore, the answer is c)",
    "An arrow flies through the air and punctures people's skin.\nMosquitos also fly through the air and puncture people's skin.\nSo the speaker is saying that mosquitos fly through the air and into people.\nTherefore, the answer is c).",
    "The yellow pages provide information about companies.\nBillboards on the highway also provide information about companies.\nSo the speaker is saying that billboards provide information about companies.\nTherefore, the answer is a).",
    "A black cavern is mysterious.\nSilence can also be mysterious.\nSo the speaker is saying that silence is mysterious.\nTherefore, the answer is c).",
    "A worm that lives on a carcass is small and irrelevant on the scale of the carcass.\nPeople are small and irrelevant on the scale of the earth.\nSo the speaker is saying that a person's life is small and irrelevant.\nTherefore, the answer is a).",
    "Dimples give character to a person's face.\nThe moon has craters that give it character.\nSo the speaker is saying that craters give character to the moon's surface.\nTherefore, the answer is d).",
    "Aprons prevent risk to cooks.\nSilence can also prevent risk by avoiding confrontations.\nSo the speaker is saying that silence prevents risk.\nTherefore, the answer is b).",
    "A sponge absorbs liquids.\nHistory can absorb things, like people and stories.\nSo the speaker is saying that history absorbs people and stories.\nTherefore, the answer is b).",
    "Hawks among fowl uses violence to attack the fowl who are not violent.\nTerrorists also use violence against people who are not violent.\nSo the speaker is saying that terrorists are people who seek to use violence among people who don't wish to use violence.\nTherefore, the answer is b).",
    "A quarterback is in charge of a football team.\nA sea captain is also in charge of a ship.\nSo the speaker is saying that the sea captain is in charge of his ship.\nTherefore, the answer is b).",
    "Draperies cover the light from the windows they are front of.\nThunderclouds cover the sun.\nSo the speaker is saying that thunderclouds cover the sun.\nTherefore, the answer is c).",
    "Shepherds monitor their sheep to keep them secure.\nSpy satellites also do monitoring to maintain national security.\nSo the speaker is saying that the spy satellite helps monitor our nation's security.\nTherefore, the answer is a).",
    "A sea is vast.\nA desert can also be vast.\nSo the speaker is saying that a desert is vast.\nTherefore, the answer is a).",
    "A vast laboratory is unpredictable.\nNature can also be unpredictable.\nSo the speaker is saying that nature is an unpredictable place.\nTherefore, the answer is a)."
]

# %%
len(qud_rationales)
# Out:
# 30

# %%
df_prompts["QUD_rationale"] = qud_rationales
df_prompts["similarity_rationale"] = similarity_rationales

# %%
df_prompts[["Statement", "Good (4)", "QUD_rationale", "similarity_rationale"]]
# Out:
#                                             Statement  \
# 0                   An idea is a kettle on the stove.
# 1                                  Happiness is gold.
# 2                          A lottery is a rich uncle.
# 3                             A storm is a coffeepot.
# 4                               The wind is an arrow.
# 5                      Time is a transforming chisel.
# 6                       Criticism is a branding iron.
# 7                              An ant is a bulldozer.
# 8                             The wind is a wrestler.
# 9                                Time is a physician.
# 10                       Age is an altar of memories.
# 11                              Genes are blueprints.
# 12                         History is an alarm clock.
# 13                       A bagpipe is a newborn baby.
# 14                   Mankind is a prisoner of wishes.
# 15                               Power is penicillin.
# ...

# %%
df_prompts.to_csv(here("data/prompts/katz/train-rationales.csv"))
